# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Sebastian Andruszczak**
#
# Data Scientist

# %% [markdown]
# I am interested in data science because I love to work with data and the technology at the same time. I also believe that learning Data Science it still can ba a beneficial way to invest time and the effort.

# %% [markdown]
# ### My code below is going to show a result of summing two numbers

# %%
1+1
# Out:
# 2

# %% [markdown]
# - Bulleted list
# 2. Numbered list
# 3. [My LinkedIn Profile](https://www.linkedin.com/in/sebastianandruszczak/)
# 4. > This is a blockquote
